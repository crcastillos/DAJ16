# %% [markdown]
# <a href="https://colab.research.google.com/github/crcastillos/DAJ16/blob/Colab/Practica_1_kodigo_16_09_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola, mundo")
# Out:
# Hola, mundo

# %%
mensaje = "Hola, mundo"
print(mensaje)
# Out:
# Hola, mundo

# %%
if 5 > 2:
  print("Cinco es mayor que dos")
# Out:
# Cinco es mayor que dos
